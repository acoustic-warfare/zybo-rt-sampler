# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
FILE = "4.npy"
# FILE = input("Which npy file to use: ")
data = np.load(FILE)

# %%
# plt.plot(data[100, 1000:3000]), data.shape
plt.set_cmap("magma")
# plt.specgram(data[4])
# for i in range(len(data)):
#     if np.mean(data[i]) == 0:
#         print(i)
n = 5
plt.plot(data[33][256*n:256*(n+1)])

# %%
from record import get_recording

# %%
signals = get_recording(2)

# %%
# %matplotlib qt
# plt.specgram(signals[0])

signals = data
for i in range(6):
    plt.plot(signals[i][:100], label=f"{i}")

plt.legend()
plt.show()
